# %% [markdown]
# ### Código para normalizar os valores

# %%
for i in range(1,100):
    if i % 2 == 0:
        print(f"{i} é par")
    else:
        print(f"{i} é ímpar")
# Out:
# 1 é ímpar
# 2 é par
# 3 é ímpar
# 4 é par
# 5 é ímpar
# 6 é par
# 7 é ímpar
# 8 é par
# 9 é ímpar
# 10 é par
# 11 é ímpar
# 12 é par
# 13 é ímpar
# 14 é par
# 15 é ímpar
# 16 é par
# 17 é ímpar
# 18 é par
# 19 é ímpar
# 20 é par
# 21 é ímpar
# 22 é par
# 23 é ímpar
# 24 é par
# 25 é ímpar
# 26 é par
# 27 é ímpar
# 28 é par
# 29 é ímpar
# 30 é par
# 31 é ímpar
# 32 é par
# 33 é ímpar
# 34 é par
# 35 é ímpar
# 36 é par
# 37 é ímpar
# 38 é par
# 39 é ímpar
# 40 é par
# 41 é ímpar
# 42 é par
# 43 é ímpar
# 44 é par
# 45 é ímpar
# 46 é par
# 47 é ímpar
# 48 é par
# 49 é ímpar
# 50 é par
# 51 é ímpar
# 52 é par
# 53 é ímpar
# 54 é par
# 55 é ímpar
# 56 é par
# 57 é ímpar
# 58 é par
# 59 é ímpar
# 60 é par
# 61 é ímpar
# 62 é par
# 63 é ímpar
# 64 é par
# 65 é ímpar
# 66 é par
# 67 é ímpar
# 68 é par
# 69 é ímpar
# 70 é par
# 71 é ímpar
# 72 é par
# 73 é ímpar
# 74 é par
# 75 é ímpar
# 76 é par
# 77 é ímpar
# 78 é par
# 79 é ímpar
# 80 é par
# 81 é ímpar
# 82 é par
# 83 é ímpar
# 84 é par
# ...
